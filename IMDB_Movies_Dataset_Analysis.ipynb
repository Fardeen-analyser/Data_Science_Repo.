# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\IMDB-Movie-Data.csv")
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# Shape of Our Dataset

# %%
data.shape
print("number of rows:",data.shape[0])
print("number of columns:",data.shape[1])
# Out:
# number of rows: 1000
# number of columns: 12

# %% [markdown]
# Information of Our Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
print("NULL Values in Revenue (Millions):",data["Revenue (Millions)"]. isnull().sum())
print("In this dataset, Revenue (Millions) column has 128 null values ")
# Out:
# NULL Values in Revenue (Millions): 128
# In this dataset, Revenue (Millions) column has 128 null values

# %%
print("NULL Values in Metascore :",data["Metascore"]. isnull().sum())
print("In this dataset, Metascore column has 64 null values ")
# Out:
# NULL Values in Metascore : 64
# In this dataset, Metascore column has 64 null values

# %% [markdown]
# Checking Missing Values In Dataset

# %%
print("any missing value:",data.isnull().values.any())
data.isnull().sum()
# Out:
# any missing value: True
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
sns.heatmap(data.isnull())
per_missing=data.isnull().sum()
per_missing
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# ###Drop All The Missing Values

# %%
data.dropna(axis=0)
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.shape
# Out:
# (1000, 12)

# %% [markdown]
# Check For Duplicate Data

# %%
dup_data=data.duplicated().any()
print("Are there any duplicate values:",dup_data.sum())
data=data.drop_duplicates()
data
# Out:
# Are there any duplicate values: 0
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# Overall Statistics About The Dataframe

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [markdown]
# Title of The Movie Which Have Runtime Greater Than Equal To 180 Minutes

# %%
data.columns
data[data['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %% [markdown]
# In Which Year There Was The Highest Average Voting

# %%
fig, ax = plt.subplots(ncols=1,figsize=(8,6))
sns.barplot(x='Year',y='Votes',data=data , palette = "dark")
plt.title("votes by year",fontsize=15)
plt.xlabel("Years",fontsize=13)
plt.ylabel("Votes",fontsize=13)
for bars in ax.containers:
   ax.bar_label(bars)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14752\2374577395.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year',y='Votes',data=data , palette = "dark")

# %% [markdown]
# In Which Year There Was The Highest Average Revenue

# %%
sns.set(rc={'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
fig, ax = plt.subplots(ncols=1,figsize=(8,6))
sns.barplot(x='Year',y='Revenue (Millions)',data=data , palette= "dark", legend=True)
plt.title("Highest Average Revenue",fontsize=15)
plt.xlabel("Years",fontsize=13)
plt.ylabel("Revenue (Millions)",fontsize=13)
for bars in ax.containers:
   ax.bar_label(bars)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14752\916881197.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year',y='Revenue (Millions)',data=data , palette= "dark", legend=True)

# %% [markdown]
# The Average Rating For Every Director

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
#                                     ...
# Micheal Bafaro                      3.50
# Jonathan Holbrook                   3.20
# Shawn Burkett                       2.70
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# Top 10 Lengthy Movies Title And Runtime

# %%
top10_len = data.nlargest(10, 'Runtime (Minutes)')[['Title', 'Runtime (Minutes)']]

# %%
top10_len
# Out:
#                                         Title  Runtime (Minutes)
# 828                                Grindhouse                191
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 965                             Inland Empire                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 36                               Interstellar                169
# 75   Pirates of the Caribbean: At World's End                169
# 271         The Hobbit: An Unexpected Journey                169

# %%
fig, ax = plt.subplots(ncols=1,figsize=(8,6))
sns.barplot(data = top10_len, x = 'Runtime (Minutes)', y = 'Title', palette="dark")
for bars in ax.containers:
   ax.bar_label(bars)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14752\1031298226.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top10_len, x = 'Runtime (Minutes)', y = 'Title', palette="dark")

# %% [markdown]
# Number of Movies Per Year

# %%
data['Year'].value_counts()
sns.countplot(x='Year',data=data, palette = "dark")
plt.title("Number of movies per year",fontsize=15)
plt.xlabel("Year",fontsize=13)
plt.ylabel("Count", fontsize=13)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14752\3572763005.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Year',data=data, palette = "dark")

# %% [markdown]
# Most Popular Movies Title [Highest Revenue]

# %%
data[data['Revenue (Millions)'].max() == data['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# Display Top 10 Highest Rated Movie Titles And its Directors

# %%
highest_rated = data.nlargest(10, 'Rating')[['Title','Director','Rating']].set_index('Title')
highest_rated
# Out:
#                                 Director  Rating
# Title
# The Dark Knight        Christopher Nolan     9.0
# Inception              Christopher Nolan     8.8
# Dangal                     Nitesh Tiwari     8.8
# Interstellar           Christopher Nolan     8.6
# Kimi no na wa             Makoto Shinkai     8.6
# The Intouchables         Olivier Nakache     8.6
# The Prestige           Christopher Nolan     8.5
# The Departed             Martin Scorsese     8.5
# The Dark Knight Rises  Christopher Nolan     8.5
# Whiplash                 Damien Chazelle     8.5

# %%
fig, ax = plt.subplots(ncols=1,figsize=(8,6))
sns.barplot(data = highest_rated, y = highest_rated.index, x = 'Rating', hue = 'Director', dodge = False)
plt.legend(bbox_to_anchor=(1.05,1), loc = 2)
for bars in ax.containers:
   ax.bar_label(bars)
plt.show()

# %% [markdown]
# Display Top 10 Highest Revenue Movie Titles

# %%
largest_revenue = data.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']].set_index('Title')
largest_revenue
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# Jurassic World                                          652.18
# The Avengers                                            623.28
# The Dark Knight                                         533.32
# Rogue One                                               532.17
# Finding Dory                                            486.29
# Avengers: Age of Ultron                                 458.99
# The Dark Knight Rises                                   448.13
# The Hunger Games: Catching Fire                         424.65

# %%
fig, ax = plt.subplots(ncols=1,figsize=(8,6))
sns.barplot(data = largest_revenue, x = 'Revenue (Millions)', y = largest_revenue.index, palette = "dark")
for bars in ax.containers:
   ax.bar_label(bars)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14752\4257641724.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = largest_revenue, x = 'Revenue (Millions)', y = largest_revenue.index, palette = "dark")

# %%
data.groupby('Year')['Rating'].mean().sort_values(ascending=False)
# Out:
# Year
# 2007    7.133962
# 2006    7.125000
# 2009    6.960784
# 2012    6.925000
# 2011    6.838095
# 2014    6.837755
# 2010    6.826667
# 2013    6.812088
# 2008    6.784615
# 2015    6.602362
# 2016    6.436700
# Name: Rating, dtype: float64

# %% [markdown]
# Does Rating Affect The Revenue

# %%
sns.scatterplot(data = data.head(20), x = "Rating", y ="Revenue (Millions)",palette = "dark", color="y")
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14752\702880114.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data = data.head(20), x = "Rating", y ="Revenue (Millions)",palette = "dark", color="y")

# %%
data['Genre'].str.contains('Action').sum()
# Out:
# np.int64(303)

# %% [markdown]
# Find Unique Values From Genre

# %%
list1 = []
for item in data['Genre']:
 list1.append(item.split(','))

# %%
list1[1]
# Out:
# ['Adventure', 'Mystery', 'Sci-Fi']

# %%
one_d = []
for item in list1:
 for item1 in item:
  one_d.append(item1)

# %%
one_d_set = set(one_d)

# %%
one_d_set
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

# %% [markdown]
# How Many Films of Each Genre Were Made?

# %%
one_d = []
for item in list1:
 for item1 in item:
  one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
# ...

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 513,
#          'Action': 303,
#          'Comedy': 279,
#          'Adventure': 259,
#          'Thriller': 195,
#          'Crime': 150,
#          'Romance': 141,
#          'Sci-Fi': 120,
#          'Horror': 119,
#          'Mystery': 106,
#          'Fantasy': 101,
#          'Biography': 81,
#          'Family': 51,
#          'Animation': 49,
#          'History': 29,
#          'Sport': 18,
#          'Music': 16,
#          'War': 13,
#          'Western': 7,
#          'Musical': 5})
